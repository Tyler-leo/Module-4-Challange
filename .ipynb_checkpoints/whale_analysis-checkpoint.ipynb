# %%
 #  A Whale off the Port(folio)
 ---

 In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sn


# %matplotlib inline

# %%
# Data Cleaning

In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.

Files:

* `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.

* `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.

* `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.
# Out:
#   Input In [488]
#     In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
# Create the file path to read the CSV into a Data frame

# %%
whale_csv = Path("C:/Users/sambu/Module 4 Assignment/Resources/whale_returns.csv")

# %%
# Reading whale returns
whale_df = pd.read_csv(whale_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
# set dates in ascending order
whale_df = whale_df.sort_index()
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# Checking for null
whale_df.isnull()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                       True                True
# 2015-03-03                      False               False
# 2015-03-04                      False               False
# 2015-03-05                      False               False
# 2015-03-06                      False               False
# ...                               ...                 ...
# 2019-04-25                      False               False
# 2019-04-26                      False               False
# 2019-04-29                      False               False
# 2019-04-30                      False               False
# 2019-05-01                      False               False
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                         True                    True
# 2015-03-03                        False                   False
# 2015-03-04                        False                   False
# 2015-03-05                        False                   False
# 2015-03-06                        False                   False
# ...                                 ...                     ...
# 2019-04-25                        False                   False
# 2019-04-26                        False                   False
# 2019-04-29                        False                   False
# 2019-04-30                        False                   False
# 2019-05-01                        False                   False
#
# [1060 rows x 4 columns]

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df = whale_df.dropna().copy()
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
csvpath_algo = Path("C:/Users/sambu/Module 4 Assignment/Resources/algo_returns.csv")
algo_df = pd.read_csv(csvpath_algo, index_col="Date", infer_datetime_format=True, parse_dates=True)
# set dates in ascending order
algo_df = algo_df.sort_index()
algo_df.head(10)
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# 2014-06-04 -0.001838       NaN
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735

# %%
#Sorting the index 
algo_df.sort_index(inplace=True)
algo_df
# Out:
#               Algo 1    Algo 2
# Date
# 2014-05-28  0.001745       NaN
# 2014-05-29  0.003978       NaN
# 2014-05-30  0.004464       NaN
# 2014-06-02  0.005692       NaN
# 2014-06-03  0.005292       NaN
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1241 rows x 2 columns]

# %%
# Checking for null
algo_df.isnull()
# Out:
#             Algo 1  Algo 2
# Date
# 2014-05-28   False    True
# 2014-05-29   False    True
# 2014-05-30   False    True
# 2014-06-02   False    True
# 2014-06-03   False    True
# ...            ...     ...
# 2019-04-25   False   False
# 2019-04-26   False   False
# 2019-04-29   False   False
# 2019-04-30   False   False
# 2019-05-01   False   False
#
# [1241 rows x 2 columns]

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df = algo_df.dropna().copy()
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
algo_df.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
tsx_csv = Path("C:/Users/sambu/Module 4 Assignment/Resources/sp_tsx_history.csv")
tsx_df = pd.read_csv(tsx_csv, index_col="Date", infer_datetime_format=True, parse_dates=True)
tsx_df = tsx_df.sort_index()
tsx_df.head(10)
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99
# 2012-10-09  $12,273.57
# 2012-10-10  $12,212.42
# 2012-10-11  $12,233.95
# 2012-10-12  $12,202.04
# 2012-10-15  $12,229.96

# %%
#Sorting the index 
tsx_df.sort_index(inplace=True)
tsx_df
# Out:
#                  Close
# Date
# 2012-10-01  $12,370.19
# 2012-10-02  $12,391.23
# 2012-10-03  $12,359.47
# 2012-10-04  $12,447.68
# 2012-10-05  $12,418.99
# ...                ...
# 2019-12-20  $17,118.44
# 2019-12-23  $17,128.71
# 2019-12-24  $17,180.15
# 2019-12-27  $17,168.21
# 2019-12-30  $17,098.56
#
# [1818 rows x 1 columns]

# %%
# Check Data Types
tsx_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Typest
tsx_df['Close'] = tsx_df['Close'].replace(r'[$,]','',regex=True).astype('float64')
tsx_df.head()
# Out:
#                Close
# Date
# 2012-10-01  12370.19
# 2012-10-02  12391.23
# 2012-10-03  12359.47
# 2012-10-04  12447.68
# 2012-10-05  12418.99

# %%
#Checking Data Types
tsx_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
daily_returns = tsx_df.pct_change()
daily_returns.sort_index()
daily_returns.head()
# Out:
#             daily returns
# Date
# 2012-10-01            NaN
# 2012-10-02       0.001701
# 2012-10-03      -0.002563
# 2012-10-04       0.007137
# 2012-10-05      -0.002305

# %%
#checking for nulls
tsx_df.isnull()
# Out:
#             daily returns
# Date
# 2012-10-01          False
# 2012-10-02          False
# 2012-10-03          False
# 2012-10-04          False
# 2012-10-05          False
# ...                   ...
# 2019-12-20          False
# 2019-12-23          False
# 2019-12-24          False
# 2019-12-27          False
# 2019-12-30          False
#
# [1818 rows x 1 columns]

# %%
# Count nulls
tsx_df.isnull().sum()
# Out:
# daily returns    0
# dtype: int64

# %%
# Drop nulls
tsx_df = tsx_df.dropna().copy()
tsx_df.isnull().sum()
# Out:
# daily returns    0
# dtype: int64

# %%
tsx_df.head()
# Out:
#             daily returns
# Date
# 2012-10-01       12370.19
# 2012-10-02       12391.23
# 2012-10-03       12359.47
# 2012-10-04       12447.68
# 2012-10-05       12418.99

# %%
#Rename `Close` Column to be specific to this portfolio.
tsx_df.columns = ['daily returns']
tsx_df.head()
# Out:
#             daily returns
# Date
# 2012-10-01       12370.19
# 2012-10-02       12391.23
# 2012-10-03       12359.47
# 2012-10-04       12447.68
# 2012-10-05       12418.99

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
combined_data = pd.concat([whale_df, algo_df, daily_returns], axis="columns", join="inner")
combined_data.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-02                          NaN                     NaN -0.008158
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
#
#               Algo 2  daily returns
# Date
# 2015-03-02  0.003200       0.001950
# 2015-03-03 -0.000949      -0.008530
# 2015-03-04  0.002416      -0.003371
# 2015-03-05  0.004323       0.001344
# 2015-03-06 -0.011460      -0.009972

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolio
combined_data.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
combined_data = (1 + combined_data.sort_index()).cumprod()-1
# Plot cumulative returns
combined_data.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_data.plot.box(figsize=(30,15))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combined_data_std = combined_data.std()
combined_data_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.070271
# PAULSON & CO.INC.              0.090735
# TIGER GLOBAL MANAGEMENT LLC    0.148722
# BERKSHIRE HATHAWAY INC         0.196871
# Algo 1                         0.256966
# Algo 2                         0.116945
# Daily returns                  0.064451
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
tsx_df_std= tsx_df.std()
tsx_df_std
# Out:
# Daily returns    1328.337613
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P TSX 60
combined_data_std[(combined_data_std['Daily returns'] < combined_data_std)]
# Out:
# SOROS FUND MANAGEMENT LLC      0.070271
# PAULSON & CO.INC.              0.090735
# TIGER GLOBAL MANAGEMENT LLC    0.148722
# BERKSHIRE HATHAWAY INC         0.196871
# Algo 1                         0.256966
# Algo 2                         0.116945
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
combined_data_std(window=252).std()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [478], in <cell line: 2>()
#       1 # Calculate the annualized standard deviation (252 trading days)
# ----> 2 combined_data_std(window=252).std()
#
# TypeError: 'Series' object is not callable

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window and plot the standard Deviation
combined_data.rolling(window=21).std().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = combined_data.corr()
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.697076
# PAULSON & CO.INC.                             0.697076            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.560964            0.433034
# BERKSHIRE HATHAWAY INC                        0.750181            0.540033
# Algo 1                                        0.313795            0.266363
# Algo 2                                        0.826667            0.674015
# daily returns                                 0.673930            0.486511
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.560964
# PAULSON & CO.INC.                               0.433034
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.423524
# Algo 1                                          0.161236
# Algo 2                                          0.506689
# daily returns                                   0.440583
#
#                              BERKSHIRE HATHAWAY INC    Algo 1    Algo 2  \
# SOROS FUND MANAGEMENT LLC                  0.750181  0.313795  0.826667
# PAULSON & CO.INC.                          0.540033  0.266363  0.674015
# TIGER GLOBAL MANAGEMENT LLC                0.423524  0.161236  0.506689
# BERKSHIRE HATHAWAY INC                     1.000000  0.289378  0.684609
# Algo 1                                     0.289378  1.000000  0.284840
# Algo 2                                     0.684609  0.284840  1.000000
# daily returns                              0.557250  0.309759  0.737391
#
#                              daily returns
# SOROS FUND MANAGEMENT LLC         0.673930
# PAULSON & CO.INC.                 0.486511
# TIGER GLOBAL MANAGEMENT LLC       0.440583
# BERKSHIRE HATHAWAY INC            0.557250
# Algo 1                            0.309759
# Algo 2                            0.737391
# daily returns                     1.000000

# %%
# Display de correlation matrix
sn.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio - soros and TSX
covariance = combined_data['SOROS FUND MANAGEMENT LLC'].cov(daily_returns['daily returns'])
covariance
# Out:
# 3.710689907855223e-05

# %%
# Calculate variance of S&P TSX
variance = daily_returns['daily returns'].var()
variance
# Out:
# 4.405458170898365e-05

# %%
# Computing beta
soros_beta = covariance / variance
soros_beta
# Out:
# 0.8422937555887713

# %%
# Plot beta trend
rolling_covariance = combined_data['SOROS FUND MANAGEMENT LLC'].rolling(window=30).cov(daily_returns['daily returns'])
rolling_variance = daily_returns['daily returns'].rolling(window=30).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(30, 10), title='Rolling 30-Day Beta of SOROS FUND MANAGMENT LLC')
# Out:
# <AxesSubplot:title={'center':'Rolling 30-Day Beta of SOROS FUND MANAGMENT LLC'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (combined_data.mean() * 252) / (combined_data.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.473237
# Algo 2                         0.402526
# daily returns                  0.199724
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharp Ratio")
# Out:
# <AxesSubplot:title={'center':'Sharp Ratio'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Write your answer here!

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
tsla_csv = Path("C:/Users/sambu/Module 4 Assignment/Resources/Google Finance Investment Tracker - Price History.csv")

# %%
tsla_df = pd.read_csv(tsla_csv, index_col='Date', infer_datetime_format=True, parse_dates=True)

# %%
# set dates in ascending order
tsla_df = tsla_df.sort_index()
tsla_df = tsla_df.drop(columns=['Open', 'High', 'Low', 'Volume'])
tsla_df.head()
# Out:
#              Close
# Date
# 2021-06-21  620.83
# 2021-06-22  623.71
# 2021-06-23  656.57
# 2021-06-24  679.82
# 2021-06-25  671.87

# %%
# Reading data from 2nd stock
msft_csv = Path("C:/Users/sambu/Module 4 Assignment/Resources/Google Finance Investment Tracker - Price History (msft).csv")

# %%
msft_df = pd.read_csv(msft_csv, index_col='Date', infer_datetime_format=True, parse_dates=True)

# %%
# set dates in ascending order
msft_df = msft_df.sort_index()
msft_df = msft_df.drop(columns=['Open', 'High', 'Low', 'Volume'])
msft_df.head()
# Out:
#              Close
# Date
# 2021-06-21  262.63
# 2021-06-22  265.51
# 2021-06-23  265.27
# 2021-06-24  266.69
# 2021-06-25  265.02

# %%
# Reading data from 3rd stock
peloton_csv = Path("C:/Users/sambu/Module 4 Assignment/Resources/Google Finance Investment Tracker - Price History (Peleton).csv")

# %%
peloton_df = pd.read_csv(peloton_csv, index_col='Date', infer_datetime_format=True, parse_dates=True)

# %%
# set dates in ascending order
peloton_df = peloton_df.sort_index()
peloton_df = peloton_df.drop(columns=['Open', 'High', 'Low', 'Volume'])
peloton_df.head()
# Out:
#              Close
# Date
# 2021-06-21  108.11
# 2021-06-22  117.17
# 2021-06-23  117.48
# 2021-06-24  121.85
# 2021-06-25  121.49

# %%
# Combine all stocks in a single DataFrame
combined_stocks = pd.concat([tsla_df, msft_df, peloton_df], axis="columns", join="inner")
combined_stocks.columns = ["tsla", "msft", "peloton"]
combined_stocks.head()
# Out:
#               tsla    msft  peloton
# Date
# 2021-06-21  620.83  262.63   108.11
# 2021-06-22  623.71  265.51   117.17
# 2021-06-23  656.57  265.27   117.48
# 2021-06-24  679.82  266.69   121.85
# 2021-06-25  671.87  265.02   121.49

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol
#already coded above
#combined_stocks.columns = ["tsla", "msft", "peloton"]
combined_stocks.head()
# Out:
#               tsla    msft  peloton
# Date
# 2021-06-21  620.83  262.63   108.11
# 2021-06-22  623.71  265.51   117.17
# 2021-06-23  656.57  265.27   117.48
# 2021-06-24  679.82  266.69   121.85
# 2021-06-25  671.87  265.02   121.49

# %%
# Calculate daily returns

# Drop NAs

# Display sample data

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return

# Display sample data

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

# Plot rolling standard deviation

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios

# %%
# Visualize the sharpe ratios as a bar plot

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!
